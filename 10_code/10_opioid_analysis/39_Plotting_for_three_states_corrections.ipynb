# %%
import numpy as np
import pandas as pd
from plotnine import *

# %%
#df['LOCATION'] = df['COUNTY'] + ',' + df['STATE']
#df['Year']=df['Year'].astype(str).astype(int)
#df[df['opioids per capita'] > 50]


#df_locations = df[df['LOCATION'].isin(locations)]
#df_locations

#locations = ('MADISON,AL','NEW CASTLE,DE','HILLSBOROUGH,FL','BROWARD,FL','CLARKE,GA','HALL,GA',
#             'SAINT LOUIS CITY,MO','GREENE,MO','DELAWARE,NY','PUTNAM,NY' , 'WILSON,NC' )

#locations_out_pc = ('HILLSBOROUGH,FL', 'BROWARD,FL')

#locations_out_non_pc = ('NEW CASTLE,DE', 'PUTNAM,NY')

#locations_non = ('MADISON,AL','HALL,GA', 'CLARKE,GA', 'GREENE,MO', 'DELAWARE,NY', 'WILSON,NC')

#df.head()
# 2053, 2122

# %%
#df = df[df['opioids_per_capita'] < 1000] #dropped 44 records #9 records
#df['Year']=df['Year'].astype(str).astype(int)

# %%
df = pd.read_pickle("/Users/abhirajvinnakota/Desktop/estimating-impact-of-opioid-prescription-regulations-team-6/20_intermediate_files/10_opioids_analysis/30_final_data_sets_from_30/1.final_dataset_florida.pkl")
df['Year']=df['Year'].astype(str).astype(int)
df['policy_state'] = df['policy_state'].astype('category')

# %%
# pre-post
fig =(ggplot(df[df['policy_state'] == 1], aes(x='Year',y ='opioids_per_capita', color = 'policy_state'))
      + geom_point(df[df['policy_state'] == 1],color = 'grey', alpha = 0.2)
      + geom_smooth(df[(df['policy_state'] == 1) & (np.equal(df['pre_post'], 'pre'))], method = 'lm', se = True)
      + geom_smooth(df[(df['policy_state'] == 1) & (np.equal(df['pre_post'], 'post'))], method = 'lm', se = True)
      + geom_vline(xintercept= 2010, linetype = 'dotted')
      + labs( x = 'Year', y = 'Opioid Shipments per Capita', title ='Pre-Post Analysis - Florida (Policy Change Jan 1st 2010)', color = 'Policy State')
      + guides(fill = False, color = False, linetype = False, shape = False))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7562484109)>

# %%
#diff
fig =(ggplot(df, aes(x='Year',y ='opioids_per_capita', color = 'policy_state'))
      + geom_point(df[df['policy_state'] == 1],color = 'grey', alpha = 0.2)
      + geom_smooth(df[(df['policy_state'] == 1) & (np.equal(df['pre_post'], 'pre'))], method = 'lm',  se = True)
      + geom_smooth(df[(df['policy_state'] == 1) & (np.equal(df['pre_post'], 'post'))], method = 'lm',  se = True)
      + geom_smooth(df[(df['policy_state'] == 0) & (np.equal(df['pre_post'], 'pre'))], method = 'lm',  se = True)
      + geom_smooth(df[(df['policy_state'] == 0) & (np.equal(df['pre_post'], 'post'))], method = 'lm',  se = True)
      + geom_vline(xintercept= 2010, linetype = "dotted")
      + labs( x = 'Year', y = 'Opioid Shipments per Capita', title ='Diff-in-Diff Analysis - Florida (Policy Change Jan 1st 2010)'))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029295943308)>

# %%
df_texas = pd.read_pickle("/Users/abhirajvinnakota/Desktop/estimating-impact-of-opioid-prescription-regulations-team-6/20_intermediate_files/10_opioids_analysis/30_final_data_sets_from_30/1.final_dataset_texas.pkl")

# %%
df_texas['Year_axis'] = df_texas['Year_axis'].astype(str).astype(float)
df_texas['Year'] = df_texas['Year'].astype(str).astype(int)
df_texas['policy_state'] = df_texas['policy_state'].astype('category')

# %%
#df_texas = df_texas[df_texas['Year'] != 2007]

# %%
#pre-post
fig =(ggplot(df_texas[df_texas['policy_state'] == 1], aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['pre_post'], 'pre'))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['pre_post'], 'post'))], method = 'lm')
      + geom_vline(xintercept = 2007, linetype = "dotted")
      + labs(x = 'Year', y = 'Opioid Shipments per Capita', title ='Pre-Post Analysis - Texas (Policy Change Jan 1st 2007)')
      + guides(fill = False, color = False, linetype = False, shape = False))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029295732024)>

# %%
#yearly-trend
fig =(ggplot(df_texas, aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (df_texas['Year'] == 2006)], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2007))], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2008))], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2009))], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2010))], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2011))], method = 'loess')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2012))], method = 'loess')
      + geom_vline(xintercept= 2007, linetype = "dotted")
      + labs(x = 'Year', y = 'Opioid Shipments per Capita', title ='Yearly Trends - Texas (Policy Change Jan 1st 2007)')
      + guides(fill = False, color = False, linetype = False, shape = False))
fig
# Out:
# <ggplot: (-9223372029292286695)>

# %%
#pre-post
fig =(ggplot(df_texas, aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['pre_post'], 'pre'))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['pre_post'], 'post'))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 0) & (np.equal(df_texas['pre_post'], 'pre'))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 0) & (np.equal(df_texas['pre_post'], 'post'))], method = 'lm')
      + geom_vline(xintercept= 2007, linetype = "dotted")
      + labs( x = 'Year', y = 'Opioid Shipments per Capita', title ='Diff-in-Diff Analysis - Texas (Policy Change Jan 1st 2007)'))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029296459348)>

# %%
df_texas.head()
# Out:
#     COUNTY Month STATE  Year pre_post    Year_axis policy_state  \
# 0  AUTAUGA     1    AL  2006      pre  2006.083333          0.0
# 1  AUTAUGA     2    AL  2006      pre  2006.166667          0.0
# 2  AUTAUGA     3    AL  2006      pre  2006.250000          0.0
# 3  AUTAUGA     4    AL  2006      pre  2006.333333          0.0
# 4  AUTAUGA     5    AL  2006      pre  2006.416667          0.0
#
#    opioids_per_capita
# 0            0.003699
# 1            0.021190
# 2            0.027453
# 3            0.026157
# 4            0.024269

# %%
df1 = df_texas.groupby(['Year','policy_state'],as_index=False)['opioids_per_capita'].mean()

# %%
df1.head()
# Out:
#    Year policy_state  opioids_per_capita
# 0  2006          0.0            0.020123
# 1  2006          1.0            0.012768
# 2  2007          0.0            0.022885
# 3  2007          1.0            0.014521
# 4  2008          0.0            0.025104

# %%
df1.pivot(index='Year', columns='policy_state', values='opioids_per_capita')
# Out:
# policy_state       0.0       1.0
# Year
# 2006          0.020123  0.012768
# 2007          0.022885  0.014521
# 2008          0.025104  0.015496
# 2009          0.027719  0.016596
# 2010          0.030707  0.017416
# 2011          0.033046  0.019078
# 2012          0.034297  0.019583

# %%
df2 = df_texas.groupby(['pre_post','policy_state'],as_index=False)['opioids_per_capita'].mean()

# %%
df2.pivot(index='pre_post', columns='policy_state', values='opioids_per_capita')
# Out:
# policy_state       0.0       1.0
# pre_post
# post          0.028964  0.017118
# pre           0.020123  0.012768

# %%
df_wash = pd.read_pickle("/Users/abhirajvinnakota/Desktop/estimating-impact-of-opioid-prescription-regulations-team-6/20_intermediate_files/10_opioids_analysis/30_final_data_sets_from_30/1.final_dataset_washington.pkl")

# %%
df_wash['Year_axis'] = df_wash['Year_axis'].astype(str).astype(float)
df_wash['Year'] = df_wash['Year'].astype(str).astype(int)
df_wash['policy_state'] = df_wash['policy_state'].astype('category')

# %%
df_wash.head()
# Out:
#     COUNTY Month STATE  Year pre_post    Year_axis policy_state  \
# 0  AUTAUGA     1    AL  2006      pre  2006.083333          0.0
# 1  AUTAUGA     2    AL  2006      pre  2006.166667          0.0
# 2  AUTAUGA     3    AL  2006      pre  2006.250000          0.0
# 3  AUTAUGA     4    AL  2006      pre  2006.333333          0.0
# 4  AUTAUGA     5    AL  2006      pre  2006.416667          0.0
#
#    opioids_per_capita
# 0            0.003699
# 1            0.021190
# 2            0.027453
# 3            0.026157
# 4            0.024269

# %%
df1 = df_wash.groupby(['Year','policy_state'],as_index=False)['opioids_per_capita'].mean()

# %%
df1.pivot(index='Year', columns='policy_state', values='opioids_per_capita')
# Out:
# policy_state       0.0       1.0
# Year
# 2006          0.020123  0.024805
# 2007          0.022885  0.028311
# 2008          0.025104  0.030529
# 2009          0.027719  0.031611
# 2010          0.030707  0.033044
# 2011          0.033046  0.033264
# 2012          0.034297  0.033074

# %%
df2 = df_wash.groupby(['pre_post','policy_state'],as_index=False)['opioids_per_capita'].mean()

# %%
df2.pivot(index='pre_post', columns='policy_state', values='opioids_per_capita')
# Out:
# policy_state       0.0       1.0
# pre_post
# post          0.033672  0.033169
# pre           0.025303  0.029657

# %%
#pre-post
fig =(ggplot(df_wash, aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2006))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2007))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2008))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2009))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2010))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2011))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['Year'], 2012))], method = 'lm')
      + geom_vline(xintercept= 2012, linetype = "dotted"))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7558334002)>

# %%
#pre-post
fig =(ggplot(df_texas, aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2006))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2007))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2008))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2009))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2010))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2011))], method = 'lm')
      + geom_smooth(df_texas[(df_texas['policy_state'] == 1) & (np.equal(df_texas['Year'], 2012))], method = 'lm')
      + geom_vline(xintercept= 2007, linetype = "dotted"))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7555203406)>

# %%
#did
fig =(ggplot(df_wash, aes(x='Year_axis',y ='opioids_per_capita', color = 'policy_state'))
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['pre_post'], 'pre'))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 1) & (np.equal(df_wash['pre_post'], 'post'))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 0) & (np.equal(df_wash['pre_post'], 'pre'))], method = 'lm')
      + geom_smooth(df_wash[(df_wash['policy_state'] == 0) & (np.equal(df_wash['pre_post'], 'post'))], method = 'lm')
      + geom_vline(xintercept= 2012, linetype = "dotted"))
fig
# Out:
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/abhirajvinnakota/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7551018749)>

# %%
df_wash_2010 = df_wash[df_wash['Year_axis'] >= 2010]
